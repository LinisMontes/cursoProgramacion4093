# %% [markdown]
# # Operadores matematicos en python

# %%
num1 = 4
num2 = 5
resultado = num1 + num2
print(resultado)
# Out:
# 9

# %%
# Por defecto la funcion default input() - str
num1 = int(input("Digite el numero 1: "))
num2 = int(input("Digite el numero 2: "))
res = num1 + num2
print(res)
# Out:
# Digite el numero 1: 8
# Digite el numero 2: 4
# 12

# %%
num1 = float(input("Digite el numero 1: "))
num2 = float(input("Digite el numero 2: "))
res = num1 + num2
print("La suma es = {}".format(res))
# Out:
# Digite el numero 1: 1.2
# Digite el numero 2: 1.3
# 2.5

# %%
num1 = float(input("Digite el numero 1: "))
num2 = float(input("Digite el numero 2: "))
res = num1 + num2
print("La suma entre {} y {} es= {}".format(num1, num2, res))
# Out:
# Digite el numero 1: 7
# Digite el numero 2: 13
# La suma es 7.0 y 13.0 es= 20.0

# %%
num1 = int(input("Digite el numero 1: "))
num2 = int(input("Digite el numero 2: "))
res = num1 + num2

print(res)
