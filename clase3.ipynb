# %%
num1 = 8
num2 = 2

if num1 == num2:
  print("Los numeros son iguales")
else:
  print("Los numeros NO son iguales")
# Out:
# Los numeros NO son iguales

# %%
num1 = 8
num2 = 8

if num1 == num2:
  print("Los numeros son iguales")
else:
  print("Los numeros NO son iguales")
# Out:
# Los numeros son iguales

# %% [markdown]
# # Operadores relacionales

# %% [markdown]
# > mayorque, < menor que, >= mayor o igual que, <= menor o igual que, == igual que, != diferente que, ambos deben ser iguales **and**, uno de los dos debe ser verdadero **or,in** texto inmerso en otro

# %%
num = int(input("Digite el numero: "))

if num > 20:
  print("El numero es mayor a 20")
elif num > 15:
  print("El numero es mayor a 15")
elif num > 10:
  print("El numero es mayor a 10")
elif num > 5:
  print("El numero es mayor a 5")
else:
  print("No se cumple ninguna condicion")
# Out:
# Digite el numero: 18
# El numero es mayor a 15

# %%
edad = int(input("Digite su edad: "))

if edad >= 13 and edad <20:
  print("Eres un adolescente")
else:
  print("No eres un adolescente")
# Out:
# Digite su edad: 18
# Eres un adolescente

# %%
usuario = input("Digite su usuario: ")

# %%
palabra = input("Digite la palabra: ")

if palabra in "lina catalina":
  print("Verdadero")
else: 
  print("Falso")

# %%
compra = float(input("¿Cuanto fue el total de la compra? $"))

if compra > 1000000:
  descu = compra * 0.10
  total = compra - descu
  print("El descuento es = {:,.0f} y el total a pagar es= {:,.0f}".format(descu, total))
else:
  print()

# %%
cal1 = float(input("Digite la calificacion 1: "))
cal2 = float(input("Digite la calificacion 2: "))
cal3 = float(input("Digite la calificacion 3: "))

prom = round((cal1 + cal2 + cal3)/3, 2)

if prom < 3.0:
  estado = "Reprobado"
else:
  estado = "Aprobado"
print(f"El promedio es= {prom} y el estado es {estado}")
# Out:
# Digite la calificacion 1: 4.5
# Digite la calificacion 2: 3.5
# Digite la calificacion 3: 4.7
# El promedio es= 4.23 y el estado es Aprobado
